# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltS
import seaborn as sns

# %%
df_inr = pd.read_csv("data_inr.csv")

# %%
df_etf = pd.read_csv("data_ETF.csv")

# %%
print("INR DATA")
print(df_inr.shape)
print(df_inr.columns)
print(df_inr.head())

print("\nETF DATA")
print(df_etf.shape)
print(df_etf.columns)
print(df_etf.head())
# Out:
# INR DATA
# (477, 3)
# Index(['Unnamed: 0', 'Name', 'Indian rupee'], dtype='object')
#    Unnamed: 0        Name  Indian rupee
# 0           0  1978-12-31           0.0
# 1           1  1979-01-31        1852.8
# 2           2  1979-02-28        2010.4
# 3           3  1979-03-30        1974.9
# 4           4  1979-04-30        1960.9
#
# ETF DATA
# (2728, 7)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2007-12-31  82.739998  82.830002  81.980003  82.459999  82.459999   3815600
# 1  2008-01-02  83.559998  85.139999  83.440002  84.860001  84.860001  12291100
# 2  2008-01-03  84.870003  85.940002  84.599998  85.570000  85.570000   9553900
# 3  2008-01-04  85.339996  85.550003  84.430000  85.129997  85.129997   8402200
# 4  2008-01-07  85.239998  85.260002  84.570000  84.769997  84.769997   6944300

# %%
print("INR DATA")
print(df_inr.info())
print("\nMissing values:")
print(df_inr.isnull().sum())

print("\nETF DATA")
print(df_etf.info())
print("\nMissing values:")
print(df_etf.isnull().sum())

print("\nDuplicate rows in INR:", df_inr.duplicated().sum())
print("Duplicate rows in ETF:", df_etf.duplicated().sum())
# Out:
# INR DATA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    477 non-null    int64
#  1   Name          477 non-null    object
#  2   Indian rupee  477 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.3+ KB
# None
#
# Missing values:
# Unnamed: 0      0
# Name            0
# Indian rupee    0
# dtype: int64
#
# ETF DATA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2728 entries, 0 to 2727
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2728 non-null   object
#  1   Open       2728 non-null   float64
#  2   High       2728 non-null   float64
#  3   Low        2728 non-null   float64
#  4   Close      2728 non-null   float64
#  5   Adj Close  2728 non-null   float64
#  6   Volume     2728 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 149.3+ KB
# None
#
# Missing values:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Duplicate rows in INR: 0
# Duplicate rows in ETF: 0

# %%
# Converting date columns into proper datetime format

df_inr["Name"] = pd.to_datetime(df_inr["Name"])
df_etf["Date"] = pd.to_datetime(df_etf["Date"])

print("INR date range:", df_inr["Name"].min(), "to", df_inr["Name"].max())
print("ETF date range:", df_etf["Date"].min(), "to", df_etf["Date"].max())
# Out:
# INR date range: 1978-12-31 00:00:00 to 2018-08-31 00:00:00
# ETF date range: 2007-12-31 00:00:00 to 2018-10-29 00:00:00

# %%
# Long-term historical gold price trend in INR

plt.figure(figsize=(12, 5))

plt.plot(df_inr["Name"], df_inr["Indian rupee"])

plt.title("Long-Term Gold Price Trend in Indian Rupees")
plt.xlabel("Year")
plt.ylabel("Gold Price (INR)")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Gold ETF price trend

plt.figure(figsize=(12, 5))

plt.plot(df_etf["Date"], df_etf["Close"])

plt.title("Gold ETF Price Trend")
plt.xlabel("Year")
plt.ylabel("ETF Closing Price")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Summary statistics of the additional datasets

print("INR Gold Price Statistics:")
print(df_inr["Indian rupee"].describe())

print("\nETF Closing Price Statistics:")
print(df_etf["Close"].describe())
# Out:
# INR Gold Price Statistics:
# count      477.000000
# mean     26952.677987
# std      28829.499227
# min          0.000000
# 25%       6028.100000
# 50%      12449.400000
# 75%      39065.600000
# max      95072.200000
# Name: Indian rupee, dtype: float64
#
# ETF Closing Price Statistics:
# count    2728.000000
# mean      122.325073
# std        22.912403
# min        70.000000
# 25%       110.560000
# 50%       120.255001
# 75%       131.312500
# max       184.589996
# Name: Close, dtype: float64

# %%
# Check the date range of both datasets

df_inr["Name"] = pd.to_datetime(df_inr["Name"])

df_etf["Date"] = pd.to_datetime(df_etf["Date"])

print("INR dataset:")
print("Start date:", df_inr["Name"].min())
print("End date:", df_inr["Name"].max())

print("\nETF dataset:")
print("Start date:", df_etf["Date"].min())
print("End date:", df_etf["Date"].max())
# Out:
# INR dataset:
# Start date: 1978-12-31 00:00:00
# End date: 2018-08-31 00:00:00
#
# ETF dataset:
# Start date: 2007-12-31 00:00:00
# End date: 2018-10-29 00:00:00

# %%
# Summary statistics of the additional datasets

print("INR Gold Price Statistics:")
print(df_inr["Indian rupee"].describe())

print("\nETF Closing Price Statistics:")
print(df_etf["Close"].describe())
# Out:
# INR Gold Price Statistics:
# count      477.000000
# mean     26952.677987
# std      28829.499227
# min          0.000000
# 25%       6028.100000
# 50%      12449.400000
# 75%      39065.600000
# max      95072.200000
# Name: Indian rupee, dtype: float64
#
# ETF Closing Price Statistics:
# count    2728.000000
# mean      122.325073
# std        22.912403
# min        70.000000
# 25%       110.560000
# 50%       120.255001
# 75%       131.312500
# max       184.589996
# Name: Close, dtype: float64

# %%
# Feature Engineering

# Lag features: previous prices
df["Price_Lag_1"] = df["Price"].shift(1)
df["Price_Lag_7"] = df["Price"].shift(7)
df["Price_Lag_30"] = df["Price"].shift(30)

# Moving averages
df["MA_7"] = df["Price"].rolling(window=7).mean()
df["MA_30"] = df["Price"].rolling(window=30).mean()
df["MA_90"] = df["Price"].rolling(window=90).mean()

# Momentum: change in price over 7 days
df["Momentum_7"] = df["Price"] - df["Price_Lag_7"]

# 30-day rolling volatility
df["Volatility_30"] = df["Daily_Return"].rolling(window=30).std()

print(df[[
    "Date",
    "Price",
    "Price_Lag_1",
    "Price_Lag_7",
    "Price_Lag_30",
    "MA_7",
    "MA_30",
    "MA_90",
    "Momentum_7",
    "Volatility_30"
]].tail())
# Out:
#            Date  Price  Price_Lag_1  Price_Lag_7  Price_Lag_30         MA_7  \
# 2779 2018-11-12   3101       3102.0       3173.0        3184.0  3124.000000
# 2780 2018-11-13   3078       3101.0       3165.0        3184.0  3111.571429
# 2781 2018-11-14   3073       3078.0       3158.0        3207.0  3099.428571
# 2782 2018-11-15   3079       3073.0       3139.0        3187.0  3090.857143
# 2783 2018-11-16   3099       3079.0       3101.0        3187.0  3090.571429
#
#             MA_30        MA_90  Momentum_7  Volatility_30
# 2779  3173.366667  3090.033333       -72.0       0.397203
# 2780  3169.833333  3091.200000       -87.0       0.414301
# 2781  3165.366667  3092.655556       -85.0       0.383183
# 2782  3161.766667  3094.200000       -60.0       0.376764
# 2783  3158.833333  3096.022222        -2.0       0.401410

# %%
# Remove rows with missing values created by lag features

df = df.dropna().reset_index(drop=True)

print("Dataset shape after feature engineering:", df.shape)
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape after feature engineering: (2695, 15)
#
# Missing values:
# Date             0
# Price            0
# Daily_Return     0
# MA_7             0
# MA_30            0
# Volatility_30    0
# Is_Anomaly       0
# Year             0
# Month            0
# Price_Range      0
# Price_Lag_1      0
# Price_Lag_7      0
# Price_Lag_30     0
# MA_90            0
# Momentum_7       0
# dtype: int64

# %%
# Create SQLite database for GoldSense

import sqlite3

# Create/connect to the database
conn = sqlite3.connect("goldsense.db")

# Store the feature-engineered dataset in a SQL table
df.to_sql("gold_prices", conn, if_exists="replace", index=False)

print("GoldSense database created successfully.")
# Out:
# GoldSense database created successfully.

# %%
# SQL Query 1: Find the highest gold price

query = """
SELECT Date, Price
FROM gold_prices
ORDER BY Price DESC
LIMIT 10;
"""

result = pd.read_sql_query(query, conn)

print(result)
# Out:
#                   Date  Price
# 0  2013-09-03 00:00:00   3439
# 1  2013-08-27 00:00:00   3371
# 2  2013-08-29 00:00:00   3360
# 3  2013-08-28 00:00:00   3329
# 4  2013-09-02 00:00:00   3305
# 5  2013-08-30 00:00:00   3303
# 6  2013-08-31 00:00:00   3298
# 7  2013-09-01 00:00:00   3298
# 8  2013-09-04 00:00:00   3260
# 9  2012-11-26 00:00:00   3235

# %%
print("\nETF descriptive statistics:")
print(df_etf.describe())
# Out:
# ETF descriptive statistics:
#                                 Date         Open         High          Low  \
# count                           2728  2728.000000  2728.000000  2728.000000
# mean   2013-05-30 16:23:55.777126144   122.329927   122.955198   121.660242
# min              2007-12-31 00:00:00    69.300003    71.889999    66.000000
# 25%              2010-09-14 18:00:00   110.584997   111.132499   109.919998
# 50%              2013-06-01 12:00:00   120.250000   120.785000   119.735000
# 75%              2016-02-16 06:00:00   131.190003   132.025002   130.342503
# max              2018-10-29 00:00:00   184.580002   185.850006   182.100006
# std                              NaN    22.910665    22.946906    22.833307
#
#              Close    Adj Close        Volume
# count  2728.000000  2728.000000  2.728000e+03
# mean    122.325073   122.325073  1.120603e+07
# min      70.000000    70.000000  1.501600e+06
# 25%     110.560000   110.560000  6.472975e+06
# 50%     120.255001   120.255001  9.286950e+06
# 75%     131.312500   131.312500  1.365135e+07
# max     184.589996   184.589996  9.380420e+07
# std      22.912403    22.912403  7.541822e+06

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv(r"C:\Users\Admin\datasetfull.csv", header=None)

print(df.shape)
print(df.head())
print(df.tail())
print(df.info())
# Out:
# (2873, 2)
#             0     1
# 0  31-01-2011  1998
# 1  30-01-2011  1961
# 2  29-01-2011  1961
# 3  28-01-2011  1957
# 4  27-01-2011  1996
#                0     1
# 2868  05-11-2018  3173
# 2869  04-11-2018  3176
# 2870  03-11-2018  3176
# 2871  02-11-2018  3175
# 2872  01-11-2018  3187
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2873 entries, 0 to 2872
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2873 non-null   object
#  1   1       2873 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 45.0+ KB
# None

# %% [markdown]
# ## Give the columns proper names

# %%
df.columns = ["Date", "Price"]

print(df.head())
print(df.dtypes)
# Out:
#          Date  Price
# 0  31-01-2011   1998
# 1  30-01-2011   1961
# 2  29-01-2011   1961
# 3  28-01-2011   1957
# 4  27-01-2011   1996
# Date     object
# Price     int64
# dtype: object

# %% [markdown]
# ## Convert Date

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

print(df.dtypes)
print(df.head())
# Out:
# Date     datetime64[ns]
# Price             int64
# dtype: object
#         Date  Price
# 0 2011-01-31   1998
# 1 2011-01-30   1961
# 2 2011-01-29   1961
# 3 2011-01-28   1957
# 4 2011-01-27   1996

# %% [markdown]
# ## Sort the data by date

# %%
df = df.sort_values("Date").reset_index(drop=True)

print(df.head())
print(df.tail())
# Out:
#         Date  Price
# 0 2011-01-01   2069
# 1 2011-01-02   2069
# 2 2011-01-03   2076
# 3 2011-01-04   2076
# 4 2011-01-05   2049
#            Date  Price
# 2868 2018-11-12   3101
# 2869 2018-11-13   3078
# 2870 2018-11-14   3073
# 2871 2018-11-15   3079
# 2872 2018-11-16   3099

# %% [markdown]
# ## Check data quality

# %%
print("Missing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())

print("\nPrice <= 0:", (df["Price"] <= 0).sum())
# Out:
# Missing values:
# Date     0
# Price    0
# dtype: int64
#
# Duplicate rows: 0
#
# Price <= 0: 0

# %% [markdown]
# ## Check the date range and basic price statistics

# %%
print("Date range:", df["Date"].min(), "to", df["Date"].max())

print("\nPrice statistics:")
print(df["Price"].describe())
# Out:
# Date range: 2011-01-01 00:00:00 to 2018-11-16 00:00:00
#
# Price statistics:
# count    2873.000000
# mean     2819.639749
# std       256.236196
# min      1957.000000
# 25%      2686.000000
# 50%      2866.000000
# 75%      2993.000000
# max      3439.000000
# Name: Price, dtype: float64

# %% [markdown]
# ## First EDA: Overall Gold Price Trend

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.plot(df["Date"], df["Price"])

plt.title("Gold Price Trend (2011–2018)")
plt.xlabel("Date")
plt.ylabel("Gold Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Daily percentage change in gold price
df["Daily_Return"] = df["Price"].pct_change() * 100

print(df[["Date", "Price", "Daily_Return"]].head(10))
# Out:
#         Date  Price  Daily_Return
# 0 2011-01-01   2069           NaN
# 1 2011-01-02   2069      0.000000
# 2 2011-01-03   2076      0.338328
# 3 2011-01-04   2076      0.000000
# 4 2011-01-05   2049     -1.300578
# 5 2011-01-06   2043     -0.292826
# 6 2011-01-07   2035     -0.391581
# 7 2011-01-08   2024     -0.540541
# 8 2011-01-09   2024      0.000000
# 9 2011-01-10   2045      1.037549

# %% [markdown]
# ### Moving Averages

# %%
# Calculate moving averages to understand short-term and long-term trends
df["MA_7"] = df["Price"].rolling(window=7).mean()
df["MA_30"] = df["Price"].rolling(window=30).mean()

print(df[["Date", "Price", "MA_7", "MA_30"]].head(35))
# Out:
#          Date  Price         MA_7        MA_30
# 0  2011-01-01   2069          NaN          NaN
# 1  2011-01-02   2069          NaN          NaN
# 2  2011-01-03   2076          NaN          NaN
# 3  2011-01-04   2076          NaN          NaN
# 4  2011-01-05   2049          NaN          NaN
# 5  2011-01-06   2043          NaN          NaN
# 6  2011-01-07   2035  2059.571429          NaN
# 7  2011-01-08   2024  2053.142857          NaN
# 8  2011-01-09   2024  2046.714286          NaN
# 9  2011-01-10   2045  2042.285714          NaN
# 10 2011-01-11   2042  2037.428571          NaN
# 11 2011-01-12   2047  2037.142857          NaN
# 12 2011-01-13   2045  2037.428571          NaN
# 13 2011-01-14   2039  2038.000000          NaN
# 14 2011-01-15   2031  2039.000000          NaN
# 15 2011-01-16   2031  2040.000000          NaN
# 16 2011-01-17   2029  2037.714286          NaN
# 17 2011-01-18   2033  2036.428571          NaN
# 18 2011-01-19   2037  2035.000000          NaN
# 19 2011-01-20   2036  2033.714286          NaN
# 20 2011-01-21   2011  2029.714286          NaN
# 21 2011-01-22   2006  2026.142857          NaN
# 22 2011-01-23   2006  2022.571429          NaN
# 23 2011-01-24   2012  2020.142857          NaN
# 24 2011-01-25   1982  2012.857143          NaN
# 25 2011-01-26   1991  2006.285714          NaN
# 26 2011-01-27   1996  2000.571429          NaN
# 27 2011-01-28   1957  1992.857143          NaN
# 28 2011-01-29   1961  1986.428571          NaN
# 29 2011-01-30   1961  1980.000000  2025.433333
# 30 2011-01-31   1998  1978.000000  2023.066667
# 31 2011-02-01   1993  1979.571429  2020.533333
# 32 2011-02-02   1982  1978.285714  2017.400000
# 33 2011-02-03   1978  1975.714286  2014.133333
# 34 2011-02-04   2006  1982.714286  2012.700000

# %% [markdown]
# ### Plot Moving Averages

# %%
plt.figure(figsize=(12, 5))

plt.plot(df["Date"], df["Price"], label="Gold Price")
plt.plot(df["Date"], df["MA_7"], label="7-Day Moving Average")
plt.plot(df["Date"], df["MA_30"], label="30-Day Moving Average")

plt.title("Gold Price with Moving Averages")
plt.xlabel("Date")
plt.ylabel("Gold Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 30-Day Volatility

# %%
# Calculate 30-day rolling volatility
df["Volatility_30"] = df["Daily_Return"].rolling(window=30).std()

print(df[["Date", "Daily_Return", "Volatility_30"]].tail(10))
# Out:
#            Date  Daily_Return  Volatility_30
# 2863 2018-11-07     -0.221169       0.501754
# 2864 2018-11-08     -0.601647       0.514547
# 2865 2018-11-09     -1.210577       0.556537
# 2866 2018-11-10      0.032248       0.407085
# 2867 2018-11-11      0.000000       0.398036
# 2868 2018-11-12     -0.032237       0.397203
# 2869 2018-11-13     -0.741696       0.414301
# 2870 2018-11-14     -0.162443       0.383183
# 2871 2018-11-15      0.195249       0.376764
# 2872 2018-11-16      0.649562       0.401410

# %%
plt.figure(figsize=(12, 5))

plt.plot(df["Date"], df["Volatility_30"])

plt.title("30-Day Gold Price Volatility")
plt.xlabel("Date")
plt.ylabel("Volatility (%)")

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Anomaly Detection

# %% [markdown]
# ### Detect unusual price movements using IQR

# %%
# Detect unusual gold price changes using the IQR method

Q1 = df["Daily_Return"].quantile(0.25)
Q3 = df["Daily_Return"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Lower limit:", lower_limit)
print("Upper limit:", upper_limit)
# Out:
# Lower limit: -1.0958620230974963
# Upper limit: 1.1046008564728678

# %% [markdown]
# ### Mark the anomalies

# %%
df["Is_Anomaly"] = (
    (df["Daily_Return"] < lower_limit) |
    (df["Daily_Return"] > upper_limit)
)

print("Number of anomalies:", df["Is_Anomaly"].sum())
# Out:
# Number of anomalies: 342

# %% [markdown]
# ### See the actual anomalous dates

# %%
anomalies = df[df["Is_Anomaly"] == True]

print(anomalies[["Date", "Price", "Daily_Return"]].head(20))
# Out:
#           Date  Price  Daily_Return
# 4   2011-01-05   2049     -1.300578
# 20  2011-01-21   2011     -1.227898
# 24  2011-01-25   1982     -1.491054
# 27  2011-01-28   1957     -1.953908
# 30  2011-01-31   1998      1.886792
# 34  2011-02-04   2006      1.415571
# 58  2011-02-28   2110      1.199041
# 65  2011-03-07   2124      1.724138
# 74  2011-03-16   2064     -1.338432
# 94  2011-04-05   2103      1.643306
# 104 2011-04-15   2151      1.175917
# 117 2011-04-28   2217      1.140511
# 121 2011-05-02   2253      1.303957
# 125 2011-05-06   2174     -1.806685
# 131 2011-05-12   2197     -1.258427
# 142 2011-05-23   2221      1.276790
# 156 2011-06-06   2272      2.250225
# 174 2011-06-24   2242     -1.233480
# 181 2011-07-01   2187     -1.219512
# 186 2011-07-06   2200      1.149425

# %% [markdown]
# ## yearly average price

# %%
# Calculate yearly average gold price

df["Year"] = df["Date"].dt.year

yearly_avg = df.groupby("Year")["Price"].mean()

print(yearly_avg)
# Out:
# Year
# 2011    2395.575342
# 2012    2968.844262
# 2013    2899.263158
# 2014    2792.358904
# 2015    2634.410959
# 2016    2943.863388
# 2017    2892.802740
# 2018    3059.721875
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.bar(yearly_avg.index, yearly_avg.values)

plt.title("Average Gold Price by Year")
plt.xlabel("Year")
plt.ylabel("Average Gold Price")

plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly Average Gold Price

# %%
# Calculate monthly average gold price

df["Month"] = df["Date"].dt.month

monthly_avg = df.groupby("Month")["Price"].mean()

print(monthly_avg)
# Out:
# Month
# 1     2738.721774
# 2     2788.220721
# 3     2782.846774
# 4     2777.858333
# 5     2773.983871
# 6     2788.954167
# 7     2774.616935
# 8     2882.056452
# 9     2934.400000
# 10    2904.116935
# 11    2884.287611
# 12    2807.958525
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.plot(monthly_avg.index, monthly_avg.values, marker="o")

plt.title("Average Gold Price by Month")
plt.xlabel("Month")
plt.ylabel("Average Gold Price")

plt.xticks(range(1, 13))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### High–Low Price Range

# %%
# Calculate daily price range

df["Price_Range"] = df["Price"].max() - df["Price"].min()

print("Overall Gold Price Range:", df["Price_Range"].iloc[0])
# Out:
# Overall Gold Price Range: 1482

# %% [markdown]
# ## Key Findings

# %% [markdown]
# - Gold prices showed an overall increasing trend between 2011 and 2018, although there were periods of decline and fluctuation.
# - The yearly average gold price was lowest in 2011 and highest in 2018.
# - The 7-day moving average follows short-term price movements, while the 30-day moving average shows the longer-term trend more smoothly.
# - Daily returns and 30-day volatility helped identify periods of larger price movements.
# - IQR-based anomaly detection identified unusually large daily price changes that can be investigated further.
# - Monthly analysis showed that average gold prices varied across different months, with September having the highest average in this dataset.

# %% [markdown]
# ## Conclusion
#
# The data cleaning and exploratory analysis provided a clear understanding of gold price behaviour from 2011 to 2018.
# The analysis examined price trends, daily returns, moving averages, volatility, anomalies, yearly averages, and monthly patterns.
#
# These prepared features and findings can be used by the next stages of the GoldSense project for further analysis and prediction.
